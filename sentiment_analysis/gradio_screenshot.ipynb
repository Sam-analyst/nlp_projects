# %% [markdown]
# # Just wanna show what the gradio UI looks like

# %%
from PIL import Image
from IPython.display import display

# %%
image = Image.open("gradio_example.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1288x668>
